# %%
import numpy as np
import matplotlib.pyplot as plt


plt.rcParams.update({
    "font.size": 14,          # base font size (ticks, etc.)
    "axes.titlesize": 18,     # title
    "axes.labelsize": 16,     # x and y labels
    "xtick.labelsize": 14,    # x tick labels
    "ytick.labelsize": 14,    # y tick labels
    "legend.fontsize": 14     # legend
})

# Function and derivatives
def f(x):
    return 3*x**4 - 4*x**3 + 1

def fp(x):
    return 12*x**3 - 12*x**2  # f'(x)

def fpp(x):
    return 36*x**2 - 24*x     # f''(x)

# Domain for plotting
x = np.linspace(-0.5, 1.5, 800)
y = f(x)

# Inflection points from f''(x)=0  ->  12x(3x-2)=0  ->  x=0, x=2/3
x_infl = np.array([0.0, 2/3])
y_infl = f(x_infl)

# Horizontal point of inflection: need f'(x)=0 AND f''(x)=0 -> x=0
x_hpi = 0.0
y_hpi = f(x_hpi)

# Tangent line at the horizontal inflection point (slope = f'(0) = 0)
x_tan = np.linspace(-1.0, 1.0, 200)
y_tan = y_hpi + fp(x_hpi) * (x_tan - x_hpi)

# Plot
plt.figure(figsize=(8, 5))
plt.plot(x, y, label=r"$f(x)=3x^4-4x^3+1$")
plt.scatter(x_infl, y_infl, label="Inflection points")
plt.plot(x_tan, y_tan, "--", label="Tangent at horizontal inflection")

plt.annotate("Horizontal inflection\n(0, 1)",
             xy=(x_hpi, y_hpi),
             xytext=(0.35, 1.8),
             arrowprops=dict(arrowstyle="->"))
plt.annotate("Inflection\n(0.666, 0.4074)",
             xy=(xi, yi), xytext=(50, 10), textcoords="offset points",
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=0.25"))

plt.title("Graph with Horizontal Point of Inflection")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True, alpha=0.3)
plt.legend(loc='lower left')
plt.tight_layout()
plt.show()
